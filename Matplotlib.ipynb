# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

import numpy as np
from numpy.random import rand

# %%
x = rand(100)
y = rand(100)


plt.scatter(x,y,color='cyan');
#plt.show()

# %%
x = rand(100)
y = rand(100)


plt.scatter(x,y);
#plt.show()

# %%
plt.plot([10, 20, 30, 40], '-r')
plt.title('titolo grafico')
plt.ylabel('paperino y');
plt.xlabel('pippo x');
#plit.show(lista)
